# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Cardiovascular_Disease_Dataset.csv')

# %%
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#    age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0   53       1          2        171                0                  0
# 1   40       1          0         94              229                  0
# 2   49       1          2        133              142                  0
# 3   43       1          0        138              295                  1
# 4   31       1          1        199                0                  0
#
#    restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                1           147              0      5.3      3
# 1                1           115              0      3.7      1
# 2                0           202              1      5.0      1
# 3                1           153              0      3.2      2
# 4                2           136              0      5.3      3
#
#    noofmajorvessels  target
# 0                 3       1
# 1                 1       0
# 2                 0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   gender             1000 non-null   int64
#  2   chestpain          1000 non-null   int64
#  3   restingBP          1000 non-null   int64
#  4   serumcholestrol    1000 non-null   int64
#  5   fastingbloodsugar  1000 non-null   int64
#  6   restingrelectro    1000 non-null   int64
#  7   maxheartrate       1000 non-null   int64
#  8   exerciseangia      1000 non-null   int64
#  9   oldpeak            1000 non-null   float64
#  10  slope              1000 non-null   int64
#  11  noofmajorvessels   1000 non-null   int64
#  12  target             1000 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 101.7 KB

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #exploratory data analysis

# %%
#Yellow - Diseased, Purple - Not Diseased
plt.scatter(df['maxheartrate'], df['age'], c = df['target'])

# %%
plt.scatter(df['restingBP'], df['oldpeak'], c = df['target'])

# %%
plt.scatter(df['age'], df['serumcholestrol'], c = df['target'])

# %%
from sklearn.preprocessing import StandardScaler
num_cols = ['age', 'restingBP', 'serumcholestrol', 'maxheartrate', 'oldpeak']
scaler = StandardScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])
df.head()
# Out:
#         age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0  0.210464       1          2   0.642833        -2.352717                  0
# 1 -0.517591       1          0  -1.928098        -0.622817                  0
# 2 -0.013553       1          2  -0.625938        -1.280028                  0
# 3 -0.349578       1          0  -0.458995        -0.124243                  1
# 4 -1.021629       1          1   1.577717        -2.352717                  0
#
#    restingrelectro  maxheartrate  exerciseangia   oldpeak  slope  \
# 0                1      0.044567              0  1.507245      3
# 1                1     -0.891840              0  0.576955      1
# 2                0      1.654017              1  1.332816      1
# 3                1      0.220143              0  0.286239      2
# 4                2     -0.277323              0  1.507245      3
#
#    noofmajorvessels  target
# 0                 3       1
# 1                 1       0
# ...

# %%
plt.scatter(df['maxheartrate'], df['age'], c = df['target'])

# %%
plt.scatter(df['restingBP'], df['oldpeak'], c = df['target'])

# %%
plt.scatter(df['age'], df['serumcholestrol'], c = df['target'])

# %%
df.describe()
# Out:
#                 age       gender    chestpain     restingBP  serumcholestrol  \
# count  1.000000e+03  1000.000000  1000.000000  1.000000e+03     1.000000e+03
# mean   1.421085e-16     0.765000     0.980000 -4.760636e-16    -2.486900e-17
# std    1.000500e+00     0.424211     0.953157  1.000500e+00     1.000500e+00
# min   -1.637676e+00     0.000000     0.000000 -1.928098e+00    -2.352717e+00
# 25%   -8.536164e-01     1.000000     0.000000 -7.594930e-01    -5.718265e-01
# 50%   -1.355302e-02     1.000000     1.000000 -1.584962e-01     4.950235e-02
# 75%    8.405114e-01     1.000000     2.000000  9.767200e-01     7.010478e-01
# max    1.722578e+00     1.000000     3.000000  1.611106e+00     2.194881e+00
#
#        fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  \
# count        1000.000000      1000.000000  1.000000e+03    1000.000000
# mean            0.296000         0.748000 -1.119105e-16       0.498000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Pearson Correlation (-1 to 1) , -1 -> Inversely proportional, 1 -> directly proportional
df.corr()['age']
# Out:
# age                  1.000000
# gender              -0.024717
# chestpain            0.037731
# restingBP           -0.016126
# serumcholestrol      0.035439
# fastingbloodsugar    0.049732
# restingrelectro      0.067736
# maxheartrate        -0.040092
# exerciseangia       -0.037581
# oldpeak             -0.026020
# slope               -0.015334
# noofmajorvessels     0.025407
# target               0.008356
# Name: age, dtype: float64

# %%
df.corr()['gender']
# Out:
# age                 -0.024717
# gender               1.000000
# chestpain            0.035402
# restingBP           -0.069727
# serumcholestrol     -0.120759
# fastingbloodsugar    0.023560
# restingrelectro     -0.046634
# maxheartrate         0.064606
# exerciseangia       -0.051746
# oldpeak              0.331457
# slope               -0.051957
# noofmajorvessels     0.029376
# target               0.015769
# Name: gender, dtype: float64

# %%
import seaborn as sns

# %%
df['target'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='target'>

# %%
df['target'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(df['oldpeak'])
# Out:
# <Axes: ylabel='oldpeak'>

# %%
sns.displot(df['restingBP'])

# %%
sns.scatterplot(x=df['age'], y=df['maxheartrate'], hue=df['gender'],style=df['chestpain'], size=df['restingBP'])
# Out:
# <Axes: xlabel='age', ylabel='maxheartrate'>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (30, 5))
plt.subplot(1, 2, 1)
sns.displot(df['age'])
plt.subplot(1, 2, 2) 
sns.displot(df['serumcholestrol'])
